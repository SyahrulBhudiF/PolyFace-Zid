# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

import types, sys

from tensorflow.keras.utils import get_file

from tensorflow.keras.utils import get_source_inputs

sys.modules["keras.utils.layer_utils"] = types.SimpleNamespace(
    get_source_inputs=get_source_inputs,
    convert_all_kernels_in_model=lambda model: model
)

sys.modules['keras.engine.topology'] = types.SimpleNamespace(
    get_source_inputs=get_source_inputs
)

sys.modules["keras.utils.data_utils"] = types.SimpleNamespace(get_file=get_file)

import tensorflow as tf
from tensorflow import keras
from keras import layers, models
from keras_vggface.vggface import VGGFace
import numpy as np

# %%
gg_face_extractor = VGGFace(include_top=False, input_shape=(224, 224, 3), pooling='avg')
# Out:
# Downloading data from https://github.com/rcmalli/keras-vggface/releases/download/v2.0/rcmalli_vggface_tf_notop_vgg16.h5
# 2025-09-22 04:19:49.096096: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2025-09-22 04:19:49.096124: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:160] env: CUDA_VISIBLE_DEVICES="-1"
# 2025-09-22 04:19:49.096130: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:163] CUDA_VISIBLE_DEVICES is set to -1 - this hides all GPUs from CUDA
# 2025-09-22 04:19:49.096136: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:171] verbose logging is disabled. Rerun with verbose logging (usually --v=1 or --vmodule=cuda_diagnostics=1) to get more diagnostic output from this module
# 2025-09-22 04:19:49.096142: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:176] retrieving CUDA diagnostic information for host: fedora
# 2025-09-22 04:19:49.096146: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:183] hostname: fedora
# 2025-09-22 04:19:49.096227: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:190] libcuda reported version is: 580.82.9
# 2025-09-22 04:19:49.096246: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:194] kernel reported version is: 580.82.9
# 2025-09-22 04:19:49.096250: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:284] kernel version seems to match DSO: 580.82.9
# 58909280/58909280 ━━━━━━━━━━━━━━━━━━━━ 21s 0us/step
